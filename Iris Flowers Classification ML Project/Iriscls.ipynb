# %%
#numpy is an open library
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#seaborn is an open library
import seaborn as sns

# %%
#matplot is an open library
import matplotlib.pyplot as plt

# %%
#pandas is an open library
import pandas as pd

# %%
#drf1 is a variable and here csv file is been assigned to it...
drf1= pd.read_csv("/content/iris.data")

# %%
drf1.head(7)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
drf1=pd.DataFrame(drf1)
drf1
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
#shape of drf1
drf1.shape
# Out:
# (149, 5)

# %%
drf1['Iris-setosa'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: Iris-setosa, dtype: int64

# %%
#information of drf1
drf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
drf1.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
drf1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# Length: 149, dtype: bool

# %%
#description of drf1
drf1.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#isnull() function and sum() function
drf1.isnull().sum()
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
#correlation of data
drf1.corr()
# Out:
#           5.1       3.5       1.4       0.2
# 5.1  1.000000 -0.103784  0.871283  0.816971
# 3.5 -0.103784  1.000000 -0.415218 -0.350733
# 1.4  0.871283 -0.415218  1.000000  0.962314
# 0.2  0.816971 -0.350733  0.962314  1.000000

# %%
corr= drf1.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values);

# %%
x=drf1.iloc[:,:4]
y=drf1.iloc[:,:4]
x
# Out:
#      5.1  3.5  1.4  0.2
# 0    4.9  3.0  1.4  0.2
# 1    4.7  3.2  1.3  0.2
# 2    4.6  3.1  1.5  0.2
# 3    5.0  3.6  1.4  0.2
# 4    5.4  3.9  1.7  0.4
# ..   ...  ...  ...  ...
# 144  6.7  3.0  5.2  2.3
# 145  6.3  2.5  5.0  1.9
# 146  6.5  3.0  5.2  2.0
# 147  6.2  3.4  5.4  2.3
# 148  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]

# %%
y
# Out:
#      5.1  3.5  1.4  0.2
# 0    4.9  3.0  1.4  0.2
# 1    4.7  3.2  1.3  0.2
# 2    4.6  3.1  1.5  0.2
# 3    5.0  3.6  1.4  0.2
# 4    5.4  3.9  1.7  0.4
# ..   ...  ...  ...  ...
# 144  6.7  3.0  5.2  2.3
# 145  6.3  2.5  5.0  1.9
# 146  6.5  3.0  5.2  2.0
# 147  6.2  3.4  5.4  2.3
# 148  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]

# %%
for column in drf1:
  sns.displot(x=column,data=drf1)

# %%
sns.pairplot(drf1)

# %%
drf1["Iris-setosa"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: Iris-setosa, dtype: int64

# %%
sns.violinplot(data=drf1, x='3.5')
# Out:
# <Axes: xlabel='3.5'>

# %%
sns.distplot(drf1["3.5"])
# Out:
# <Axes: xlabel='3.5', ylabel='Density'>

# %%
sns.violinplot(data=drf1, x='5.1', y='Iris-setosa')
# Out:
# <Axes: xlabel='5.1', ylabel='Iris-setosa'>

# %%
sns.countplot(data=drf1, x='Iris-setosa')
# Out:
# <Axes: xlabel='Iris-setosa', ylabel='count'>

# %%
sns.jointplot(data=drf1,x='3.5',y='5.1')

# %%
sns.jointplot(x="5.1", y="3.5", data=drf1, kind="hex",color="pink")

# %%
sns.scatterplot(data=drf1, x="1.4", y="0.2", hue="Iris-setosa")
# Out:
# <Axes: xlabel='1.4', ylabel='0.2'>

# %%
sns.lmplot(x="1.4", y="0.2", hue="Iris-setosa", data=drf1)

# %%
drf1["5.1"].max()
# Out:
# 7.9

# %%
drf1.groupby("Iris-setosa").std()["1.4"]
# Out:
# Iris-setosa
# Iris-setosa        0.175061
# Iris-versicolor    0.469911
# Iris-virginica     0.551895
# Name: 1.4, dtype: float64

# %%
#thankyou.........
#thankyou.........
